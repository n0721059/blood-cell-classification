# %%
from src.augment_dataset3 import  AugmentImageDataSet
augmenter = AugmentImageDataSet(dataset_source="./data/raw", destination="./data/Augmented")

# %%
source = augmenter.get_df()
source.augmented.sum().sum()
# Out:
# np.int64(0)

# %%
augmenter.augment_by_rotation()
# Out:
#   basophil             1218 images — generating 2282
#   eosinophil           3117 images — generating 383
#   erythroblast         1551 images — generating 1949
#   ig                   2895 images — generating 605
#   lymphocyte           1214 images — generating 2286
#   monocyte             1420 images — generating 2080
#   neutrophil           3329 images — generating 171
#   platelet             2348 images — generating 1152

# %%
augmenter.validate("Original")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# DATAFRAME INFO
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17092 entries, 0 to 17091
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Filepath   17092 non-null  object
#  1   Label      17092 non-null  object
#  2   Source     17092 non-null  object
#  3   augmented  17092 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 534.2+ KB
# None
#
# Null values per column:
# Filepath     0
# Label        0
# Source       0
# augmented    0
# dtype: int64
#
# Duplicate filepaths: 0
#
# Class distribution:
# Label
# neutrophil      3329
# eosinophil      3117
# ig              2895
# platelet        2348
# erythroblast    1551
# monocyte        1420
# basophil        1218
# lymphocyte      1214
# Name: count, dtype: int64
#
# Total samples  : 17092
# Unique classes : 8
#
# ...

# %%
augmenter.validate("Augmented")
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# DATAFRAME INFO
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10908 entries, 0 to 10907
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Filepath   10908 non-null  object
#  1   Label      10908 non-null  object
#  2   Source     10908 non-null  object
#  3   augmented  10908 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 341.0+ KB
# None
#
# Null values per column:
# Filepath     0
# Label        0
# Source       0
# augmented    0
# dtype: int64
#
# Duplicate filepaths: 0
#
# Class distribution:
# Label
# lymphocyte      2286
# basophil        2282
# monocyte        2080
# erythroblast    1949
# platelet        1152
# ig               605
# eosinophil       383
# neutrophil       171
# Name: count, dtype: int64
#
# Total samples  : 10908
# Unique classes : 8
#
# ...

# %%
augmenter.show_samples()

# %%
augmenter.plot_distribution()
# Out:
# Image count per cell type & source:
# Source        Augmented  Original  Total
# Label
# basophil           2282      1218   3500
# eosinophil          383      3117   3500
# erythroblast       1949      1551   3500
# ig                  605      2895   3500
# lymphocyte         2286      1214   3500
# monocyte           2080      1420   3500
# neutrophil          171      3329   3500
# platelet           1152      2348   3500
#
# Grand total: 28,000

# %%
OUTPUT_PATH = 'wbc_dataset.csv'
df = augmenter.get_dataframe()
df.to_csv(OUTPUT_PATH, index=False)

print(f'Saved to: {OUTPUT_PATH}')
print(f'Rows    : {len(df):,}')
print(f'Columns : {list(df.columns)}')
print()
# Out:
# Saved to: wbc_dataset.csv
# Rows    : 28,000
# Columns : ['Filepath', 'Label', 'Source', 'augmented']

# %%
augmenter.validate(df)
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# DATAFRAME INFO
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28000 entries, 0 to 27999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Filepath   28000 non-null  object
#  1   Label      28000 non-null  object
#  2   Source     28000 non-null  object
#  3   augmented  28000 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 875.1+ KB
# None
#
# Null values per column:
# Filepath     0
# Label        0
# Source       0
# augmented    0
# dtype: int64
#
# Duplicate filepaths: 0
#
# Class distribution:
# Label
# basophil        3500
# eosinophil      3500
# erythroblast    3500
# ig              3500
# lymphocyte      3500
# monocyte        3500
# neutrophil      3500
# platelet        3500
# Name: count, dtype: int64
#
# Total samples  : 28000
# Unique classes : 8
#
# ...
